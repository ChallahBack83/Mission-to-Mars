# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import matplotlib.pyplot as plt
import pandas as pd

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://data-class-mars-challenge.s3.amazonaws.com/Mars/index.html). Inspect the page to identify which elements to scrape. Note that the URL is `https://data-class-mars-challenge.s3.amazonaws.com/Mars/index.html`.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
url = 'https://data-class-mars-challenge.s3.amazonaws.com/Mars/index.html'
browser.visit(url)
html = browser.html

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
mars_soup = soup(html, 'html.parser')

# %%
# Extract all rows of data
table = mars_soup.find('table', class_='table')
table
# Out:
# <table class="table">
# <tbody><tr>
# <th>id</th>
# <th>terrestrial_date</th>
# <th>sol</th>
# <th>ls</th>
# <th>month</th>
# <th>min_temp</th>
# <th>pressure</th>
# </tr>
# <tr class="data-row">
# <td>2</td>
# <td>2012-08-16</td>
# <td>10</td>
# <td>155</td>
# <td>6</td>
# <td>-75.0</td>
# <td>739.0</td>
# </tr>
# <tr class="data-row">
# <td>13</td>
# <td>2012-08-17</td>
# <td>11</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>24</td>
# <td>2012-08-18</td>
# <td>12</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>741.0</td>
# </tr>
# <tr class="data-row">
# <td>35</td>
# <td>2012-08-19</td>
# <td>13</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>732.0</td>
# </tr>
# <tr class="data-row">
# <td>46</td>
# <td>2012-08-20</td>
# <td>14</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>57</td>
# <td>2012-08-21</td>
# <td>15</td>
# <td>158</td>
# <td>6</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
table_header = table.find_all('th')

headers=[]
for header in table_header:
    title = header.text
    headers.append(title)
    
headers
# Out:
# ['id', 'terrestrial_date', 'sol', 'ls', 'month', 'min_temp', 'pressure']

# %%
# Create an empty list
rows = []

# Loop through the scraped data to create a list of rows
data_rows = table.find_all('tr', class_='data-row')

for row in data_rows:
    value = row.find_all('td')
    cleaned_value = [ele.text.strip() for ele in value]
    rows.append(cleaned_value)
    
rows
# Out:
# [['2', '2012-08-16', '10', '155', '6', '-75.0', '739.0'],
#  ['13', '2012-08-17', '11', '156', '6', '-76.0', '740.0'],
#  ['24', '2012-08-18', '12', '156', '6', '-76.0', '741.0'],
#  ['35', '2012-08-19', '13', '157', '6', '-74.0', '732.0'],
#  ['46', '2012-08-20', '14', '157', '6', '-74.0', '740.0'],
#  ['57', '2012-08-21', '15', '158', '6', '-78.0', '740.0'],
#  ['68', '2012-08-22', '16', '158', '6', '-77.0', '740.0'],
#  ['79', '2012-08-23', '17', '159', '6', '-76.0', '742.0'],
#  ['112', '2012-08-27', '21', '161', '6', '-74.0', '741.0'],
#  ['114', '2012-08-28', '22', '162', '6', '-74.0', '742.0'],
#  ['123', '2012-08-29', '23', '162', '6', '-75.0', '741.0'],
#  ['134', '2012-08-30', '24', '163', '6', '-75.0', '742.0'],
#  ['145', '2012-08-31', '25', '163', '6', '-75.0', '743.0'],
#  ['156', '2012-09-01', '26', '164', '6', '-76.0', '745.0'],
#  ['163', '2012-09-02', '27', '164', '6', '-75.0', '743.0'],
#  ['170', '2012-09-03', '28', '165', '6', '-75.0', '745.0'],
# ...

# %%
for row in table.find_all('tr', class_='data-row'):
    data_row = row.find_all('td').text
    row_data = [td.text.strip() for td in data_row]
    rows.append(data_row)
rows

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
weather_df = pd.DataFrame(rows)
weather_df.columns = headers

# %%
# Confirm DataFrame was created successfully
weather_df
# Out:
#         id terrestrial_date   sol   ls month min_temp pressure
# 0        2       2012-08-16    10  155     6    -75.0    739.0
# 1       13       2012-08-17    11  156     6    -76.0    740.0
# 2       24       2012-08-18    12  156     6    -76.0    741.0
# 3       35       2012-08-19    13  157     6    -74.0    732.0
# 4       46       2012-08-20    14  157     6    -74.0    740.0
# ...    ...              ...   ...  ...   ...      ...      ...
# 1862  1889       2018-02-23  1973  133     5    -78.0    730.0
# 1863  1892       2018-02-24  1974  134     5    -77.0    729.0
# 1864  1894       2018-02-25  1975  134     5    -76.0    729.0
# 1865  1893       2018-02-26  1976  135     5    -77.0    728.0
# 1866  1895       2018-02-27  1977  135     5    -77.0    727.0
#
# [1867 rows x 7 columns]

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1867 non-null   object
#  1   terrestrial_date  1867 non-null   object
#  2   sol               1867 non-null   object
#  3   ls                1867 non-null   object
#  4   month             1867 non-null   object
#  5   min_temp          1867 non-null   object
#  6   pressure          1867 non-null   object
# dtypes: object(7)
# memory usage: 102.2+ KB

# %%
# Change data types for data analysis
weather_df = weather_df.astype({'id': 'int', 'sol': 'int', 'ls': 'int', 'month': 'int', 'min_temp': 'float', 'pressure': 'float'})
weather_df['terrestrial_date']= pd.to_datetime(weather_df['terrestrial_date'])

# %%
# Confirm type changes were successful by examining data types again
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1867 non-null   int32
#  1   terrestrial_date  1867 non-null   datetime64[ns]
#  2   sol               1867 non-null   int32
#  3   ls                1867 non-null   int32
#  4   month             1867 non-null   int32
#  5   min_temp          1867 non-null   float64
#  6   pressure          1867 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int32(4)
# memory usage: 73.1 KB

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
num_months = weather_df["month"].nunique()
num_months
# Out:
# 12

# %%
# 2. How many Martian days' worth of data are there?
num_days = weather_df['sol'].nunique()
num_days
# Out:
# 1867

# %%
# 3. What is the average low temperature by month?
avg_low_temp = weather_df.groupby(['month'], as_index=False)['min_temp'].mean()
avg_low_temp =pd.DataFrame(avg_low_temp)
avg_low_temp.columns = ['month','min_temp']
avg_low_temp
# Out:
#     month   min_temp
# 0       1 -77.160920
# 1       2 -79.932584
# 2       3 -83.307292
# 3       4 -82.747423
# 4       5 -79.308725
# 5       6 -75.299320
# 6       7 -72.281690
# 7       8 -68.382979
# 8       9 -69.171642
# 9      10 -71.982143
# 10     11 -71.985507
# 11     12 -74.451807

# %%
# Plot the average temperature by month
#plt.bar(avg_low_temp['month'],avg_low_temp['min_temp'], color = 'orange')

plt.bar('month','min_temp', data=avg_low_temp, color = 'orange')
tick_locations = [value for value in avg_low_temp['month']]

plt.xticks(tick_locations, avg_low_temp['month'])

plt.title("Average Minimum Temp on Mars by Month")
plt.xlabel("Month")
plt.ylabel("Temperature in Celsius")
# Out:
# Text(0, 0.5, 'Temperature in Celsius')

# %%
sorted_df = avg_low_temp.sort_values(by='min_temp',ascending=True)

sorted_df
# Out:
#     month   min_temp
# 2       3 -83.307292
# 3       4 -82.747423
# 1       2 -79.932584
# 4       5 -79.308725
# 0       1 -77.160920
# 5       6 -75.299320
# 11     12 -74.451807
# 6       7 -72.281690
# 10     11 -71.985507
# 9      10 -71.982143
# 8       9 -69.171642
# 7       8 -68.382979

# %%
# Identify the coldest and hottest months in Curiosity's location
#plt.bar('month', 'min_temp', data=sorted_df, color = 'blue)'
plt.bar('month', 'min_temp', data = sorted_df, color = 'blue')

#ticks = [value for value in sorted_df['month']]

#plt.xticks(ticks, sorted_df['month'])

plt.title("Average Minimum Temp on Mars by Month")
plt.xlabel("Month")
plt.ylabel("Temperature in Celsius")
# Out:
# Text(0, 0.5, 'Temperature in Celsius')

# %%
# 4. Average pressure by Martian month
avg_press = weather_df.groupby(['month'], as_index=False)['pressure'].mean()
avg_press = pd.DataFrame(avg_press)
avg_press.columns = ['month', 'avg_pressure']
avg_press
# Out:
#     month  avg_pressure
# 0       1    862.488506
# 1       2    889.455056
# 2       3    877.322917
# 3       4    806.329897
# 4       5    748.557047
# 5       6    745.054422
# 6       7    795.105634
# 7       8    873.829787
# 8       9    913.305970
# 9      10    887.312500
# 10     11    857.014493
# 11     12    842.156627

# %%
# Plot the average pressure by month
plt.bar(avg_press['month'],avg_press['avg_pressure'], color = 'green')

tick_locations = [value for value in avg_low_temp['month']]

plt.xticks(tick_locations, avg_low_temp['month'])

plt.title("Average Pressure on Mars by Month")
plt.xlabel("Month")
plt.ylabel("Atmospheric Pressure")
# Out:
# Text(0, 0.5, 'Atmospheric Pressure')

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
#find max/peak longitude
peak = weather_df['ls'].max()
peak
# Out:
# 359

# %%
#sort only occurances of peak longitude knowing that is one cycle.
peak_long = weather_df.loc[weather_df['ls']==peak]
peak_long
# Out:
#         id terrestrial_date   sol   ls  month  min_temp  pressure
# 302    316       2013-07-30   349  359     12     -75.0     852.0
# 303    318       2013-07-31   350  359     12     -76.0     853.0
# 923    955       2015-06-17  1017  359     12     -78.0     850.0
# 924    956       2015-06-18  1018  359     12     -79.0     850.0
# 1577  1607       2017-05-04  1686  359     12     -75.0     838.0
# 1578  1608       2017-05-05  1687  359     12     -75.0     838.0

# %%
#calculate sol days from peaks 

sol_1 = peak_long['sol'].iloc[1]
sol_2 = peak_long['sol'].iloc[2]

sols_year = sol_2 - sol_1
sols_year
# Out:
# 667

# %%
#terrestrial days in sol year

tera_1 = peak_long['terrestrial_date'].iloc[1]
tera_2 = peak_long['terrestrial_date'].iloc[2]
terrestrial_days = tera_1 - tera_2
terrestrial_days
# Out:
# Timedelta('-686 days +00:00:00')

# %%
plt.plot(terrestrial_days, pea)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32832\2112142974.py in <module>
# ----> 1 plt.plot(terrestrial_days, sol_year)
#
# NameError: name 'sol_year' is not defined

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
weather_df.to_csv('mars_weather_table.csv')

# %%
browser.quit()
